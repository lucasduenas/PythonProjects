# %%
#import libraries
from bs4 import BeautifulSoup as bs
import requests

# %%
#load webpage
r = requests.get('https://en.wikipedia.org/wiki/Toy_Story_3')

#Convert to beatiful soup object

soup=bs(r.content)

#print out html
contents=soup.prettify()

# %%
info_box = soup.find(class_='infobox vevent')
info_rows = info_box.find_all('tr')

# %%
def get_content_value(row_data):
    if row_data.find('li'):
        return [li.get_text(" ", strip=True).replace("\xa0", " ") for li in row_data.find_all('li')]
    else:
        return row_data.get_text(" ", strip=True).replace("\xa0", " ")

movie_info={}

for index, row in enumerate(info_rows):
    if index == 0:
        movie_info['title']=row.find('th').get_text(" ", strip=True)
    elif index==1:
        continue
    else:
        content_key=row.find('th').get_text(" ", strip=True)
        content_value=get_content_value(row.find('td'))
        movie_info[content_key] = content_value
    
movie_info
# Out:
# {'title': 'Toy Story 3',
#  'Directed by': 'Lee Unkrich',
#  'Screenplay by': 'Michael Arndt',
#  'Story by': ['John Lasseter', 'Andrew Stanton', 'Lee Unkrich'],
#  'Produced by': 'Darla K. Anderson',
#  'Starring': ['Tom Hanks',
#   'Tim Allen',
#   'Joan Cusack',
#   'Don Rickles',
#   'Wallace Shawn',
#   'John Ratzenberger',
#   'Estelle Harris',
#   'Ned Beatty',
#   'Michael Keaton',
#   'Jodi Benson',
#   'John Morris'],
#  'Cinematography': ['Jeremy Lasky', 'Kim White'],
#  'Edited by': 'Ken Schretzmann',
#  'Music by': 'Randy Newman',
#  'Production companies': ['Walt Disney Pictures', 'Pixar Animation Studios'],
#  'Distributed by': 'Walt Disney Studios Motion Pictures',
#  'Release dates': ['June 12, 2010 ( 2010-06-12 ) ( Taormina Film Fest )',
#   'June 18, 2010 ( 2010-06-18 ) (United States)'],
#  'Running time': '103 minutes [1]',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$200 million [1]',
#  'Box office': '$1.067 billion [1]'}

# %%
##Get info box for all disney movies

# %%
#load webpage
r = requests.get('https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films')

#Convert to beatiful soup object

soup=bs(r.content)

# %%
movies = soup.select('.wikitable.sortable i')

# %%
def get_content_value(row_data):
    if row_data.find('li'):
        return [li.get_text(" ", strip=True).replace("\xa0", " ") for li in row_data.find_all('li')]
    elif row_data.find('br'):
        return [text for text in row_data.stripped_strings]
    else:
        return row_data.get_text(" ", strip=True).replace("\xa0", " ")

def clean_tags(soup):
    for tag in soup.find_all(['sup', 'span']):
        tag.decompose()
    
def get_info_box(url):
    
    #load webpage
    r = requests.get(url)
    soup=bs(r.content)
    
    info_box = soup.find(class_='infobox vevent')
    info_rows = info_box.find_all('tr')
    
    clean_tags(soup)
    
    movie_info={}
    
    for index, row in enumerate(info_rows):
        if index == 0:
            movie_info['title']=row.find('th').get_text(" ", strip=True)
        
        else:
            header=row.find('th')
            if header:
                content_key=row.find('th').get_text(" ", strip=True)
                content_value=get_content_value(row.find('td'))
                movie_info[content_key] = content_value
            
    return movie_info

# %%
get_info_box('https://en.wikipedia.org/wiki/The_Great_Locomotive_Chase')
# Out:
# {'title': 'The Great Locomotive Chase',
#  'Directed by': 'Francis D. Lyon',
#  'Written by': 'Lawrence Edward Watkin',
#  'Produced by': ['Lawrence Edward Watkin', 'Walt Disney'],
#  'Starring': ['Fess Parker',
#   'Jeffrey Hunter',
#   'John Lupton',
#   'Jeff York',
#   'Slim Pickens'],
#  'Cinematography': 'Charles Boyle',
#  'Edited by': 'Ellsworth Hoagland',
#  'Music by': 'Paul J. Smith',
#  'Production company': 'Walt Disney Productions',
#  'Distributed by': 'Buena Vista Distribution',
#  'Release date': 'June 8, 1956',
#  'Running time': '85 minutes',
#  'Country': 'United States',
#  'Language': 'English',
#  'Box office': '$1.7 million (US)'}

# %%
r = requests.get('https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films')
soup=bs(r.content)
movies = soup.select('.wikitable.sortable i a')

base_path = 'https://en.wikipedia.org/'
movie_info_list=[]
for index,movie in enumerate(movies):
    if index % 10 == 0:
        print(index)
    try:
        relative_path = movie['href']
        full_path=base_path+relative_path
        title = movie['title']
        movie_info_list.append(get_info_box(full_path))
    except Exception as e:
        print(movie.get_text())
        print(e)
# Out:
# 0
# 10
# 20
# 30
# 40
# Zorro the Avenger
# 'NoneType' object has no attribute 'find'
# The Sign of Zorro
# 'NoneType' object has no attribute 'find'
# 50
# 60
# 70
# 80
# 90
# 100
# 110
# 120
# 130
# 140
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 220
# 230
# 240
# 250
# 260
# Spirited Away
# 'NoneType' object has no attribute 'get_text'
# 270
# 280
# 290
# 300
# Howl's Moving Castle
# 'NoneType' object has no attribute 'get_text'
# 310
# 320
# The Nightmare Before Christmas 3D
# 'NoneType' object has no attribute 'get_text'
# 330
# The Secret of the Magic Gourd
# 'NoneType' object has no attribute 'get_text'
# 340
# 350
# 360
# Ponyo
# 'NoneType' object has no attribute 'get_text'
# 370
# Tales from Earthsea
# 'NoneType' object has no attribute 'get_text'
# 380
# Anaganaga O Dheerudu
# 'NoneType' object has no attribute 'get_text'
# 390
# The Secret World of Arrietty
# 'NoneType' object has no attribute 'get_text'
# 400
# 410
# 420
# 430
# Tini: The Movie
# 'NoneType' object has no attribute 'get_text'
# 440
# Born in China
# 'NoneType' object has no attribute 'get_text'
# 450
# 460
# 470
# 480
# 490
# The Beatles: Get Back – The Rooftop Concert
# 'NoneType' object has no attribute 'find'
# 500
# Wish
# 'NoneType' object has no attribute 'find_all'
# 510
# Elio
# 'NoneType' object has no attribute 'find_all'
# 61
# 'NoneType' object has no attribute 'find_all'
# 520
# All Night Long
# 'NoneType' object has no attribute 'find'
# Big Thunder Mountain Railroad
# 'NoneType' object has no attribute 'find_all'
# Keeper of the Lost Cities
# 'NoneType' object has no attribute 'find_all'
# 530
# Muppet Man
# 'NoneType' object has no attribute 'find_all'
# One Thousand and One Nights
# 'NoneType' object has no attribute 'find_all'
# Shrunk
# 'NoneType' object has no attribute 'find'
# Sister Act 3
# 'NoneType' object has no attribute 'find'
# Space Mountain
# 'NoneType' object has no attribute 'find_all'
# 540
# The Graveyard Book
# 'NoneType' object has no attribute 'find_all'
# The Thief
# 'NoneType' object has no attribute 'find_all'
# Tom Sawyer
# 'NoneType' object has no attribute 'find_all'
# Tower of Terror
# 'NoneType' object has no attribute 'find_all'
# 550
# Tron: Ares
# 'NoneType' object has no attribute 'find'
# FC Barcelona
# 'NoneType' object has no attribute 'find_all'
# Figment
# 'NoneType' object has no attribute 'find_all'

# %%
len(movie_info_list)
# Out:
# 525

# %%
##Save the data
import json

def save_data(title, data):
    with open(title, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
import json
def load_data(title):
    with open(title, encoding='utf-8') as f:
        return json.load(f)

# %%
save_data('disney_data.json', movie_info_list)

# %%
##CLEAN DATA

# %%
movie_info_list=load_data('disney_data.json')

# %%
#change running time to integer

[movie.get('Running time', 'N/A') for movie in movie_info_list]
# Out:
# ['83 minutes',
#  '88 minutes',
#  '126 minutes',
#  '74 minutes',
#  '64 minutes',
#  '70 minutes',
#  '42 minutes',
#  '65 min',
#  '71 minutes',
#  '75 minutes',
#  '94 minutes',
#  '73 minutes',
#  '75 minutes',
#  '82 minutes',
#  '68 minutes',
#  '74 minutes',
#  '96 minutes',
#  '75 minutes',
#  '84 minutes',
#  '77 minutes',
#  '92 minutes',
#  '69 minutes',
#  '81 minutes',
#  ['60 minutes (VHS and Wild Discovery version)', '71 minutes (original)'],
#  '127 minutes',
#  '93 minutes',
#  '76 minutes',
#  '75 minutes',
#  '73 minutes',
#  '85 minutes',
#  '81 minutes',
#  '70 minutes',
#  '90 min.',
#  '80 minutes',
#  '75 minutes',
#  '84 minutes',
#  '83 minutes',
#  '72 minutes',
#  '97 minutes',
#  '75 minutes',
#  '104 minutes',
#  '93 minutes',
#  '105 minutes',
#  '95 minutes',
#  '97 minutes',
#  '134 minutes',
#  '69 minutes',
#  '92 minutes',
#  '126 minutes',
#  '79 minutes',
#  '97 minutes',
#  '128 minutes',
#  '73 minutes',
#  '91 minutes',
#  '105 minutes',
#  '98 minutes',
#  '130 minutes',
#  '89 minutes',
#  '93 minutes',
#  '67 minutes',
#  '98 minutes',
#  '100 minutes',
#  '118 minutes',
#  '103 minutes',
#  '110 minutes',
#  '80 min.',
#  '79 minutes',
#  '91 minutes',
#  '91 minutes',
#  '97 minutes',
#  '118 minutes',
#  '139 minutes',
#  '131 mins.',
#  '92 minutes',
#  '87 minutes',
#  '116 minutes',
#  '93 minutes',
#  '110 min.',
#  '110 min.',
#  '131 minutes',
#  '101 minutes',
#  '108 minutes',
#  '84 minutes',
#  '78 minutes',
#  '75 minutes',
#  ['164 minutes',
#   '(',
#   'Los Angeles',
#   'premiere)',
#   '144 minutes',
#   '(',
#   'New York City',
#   'premiere)',
#   '118 minutes',
#   '(General release)',
#   '172 minutes',
#   '(',
#   "Director's cut",
#  '104 minutes',
#  '137 minutes',
#  '106 minutes',
#  '63 minutes',
#  '88 minutes',
#  '103 minutes',
#  '93 minutes',
#  '132 minutes',
#  '77 minutes',
#  '96 minutes',
#  '93 minutes',
#  '100 minutes',
#  '89 minutes',
#  '87 minutes',
#  '75 minutes',
#  '101 minutes',
#  '130 minutes',
#  '77 minutes',
#  '104 minutes',
#  '149 minutes',
#  '92 minutes',
#  '81 minutes',
#  '102 minutes',
#  '125 minutes',
#  ['107 minutes', '125 minutes (Extended Cut)'],
#  '78 minutes',
#  '77 minutes',
#  '124 minutes',
#  '97 minutes',
#  '84 minutes',
#  '127 minutes',
#  '81 minutes',
#  '102 minutes',
#  '124 minutes',
#  '129 minutes',
#  '76 minutes',
#  '106 minutes',
#  '82 minutes',
#  '130 minutes',
#  '95 minutes',
#  '154 minutes',
#  '94 minutes',
#  '117 minutes',
#  '108 minutes',
#  '106 minutes',
#  '113 minutes',
#  '97 minutes',
#  '118 minutes',
#  '103 minutes',
#  '124 minutes',
#  '107 minutes',
#  '161 minutes',
#  '86 minutes',
#  '129 minutes',
#  '129 minutes',
#  '102 minutes',
#  'N/A',
#  '162 minutes',
#  '114 minutes',
#  '105 minutes',
#  '109 minutes',
#  '118 minutes',
#  '104 minutes',
#  '99 minutes',
#  '112 minutes',
#  '131 minutes',
#  '112 minutes',
#  '76 minutes',
#  '128 minutes',
#  '100 minutes',
#  '118 minutes',
#  '119 minutes',
#  '104 minutes',
#  '100 minutes',
#  '103 minutes',
#  '114 minutes',
#  '99 minutes',
#  '102 minutes',
#  '107 minutes',
#  '78 minutes',
#  '86 minutes',
#  '95 minutes',
#  '160 minutes',
#  '85 minutes',
#  '100 minutes',
#  '95 minutes',
#  '115 minutes',
#  '110 minutes',
#  '122 minutes',
#  '101 minutes',
#  '121 minutes',
#  '95 minutes',
#  '107 minutes',
#  '134 minutes',
#  '95 minutes',
#  '128 minutes',
#  '102 minutes',
#  '58 minutes',
#  '108 minutes',
#  '82 minutes',
#  '100 minutes',
#  '107 minutes',
#  '91 minutes',
#  '84 minutes',
#  '97 minutes',
#  '105 minutes',
#  '105 minutes',
#  '111 minutes',
#  '105 minutes',
#  '103 minutes',
#  '118 minutes',
#  '102 minutes',
#  '75 minutes',
#  '77 minutes',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '95 minutes',
#  '118 minutes',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '81 minutes',
#  '70 minutes',
#  'N/A',
#  '90 minutes',
#  '93 minutes',
#  '91 minutes',
#  '78 minutes',
#  '85 minutes',
#  '124 minutes',
#  'N/A',
#  '83 minutes',
#  '107 minutes',
#  'N/A',
#  '79 minutes',
#  '508 minutes (5 films)',
#  '79 minutes',
#  '102 minutes',
#  ['468 minutes'],
#  '108 minutes',
#  '81 minutes',
#  '102 minutes',
#  '108 minutes']

# %%
def minutes_to_integer(running_time):
    if running_time=='N/A':
        return None
    if isinstance(running_time, list):
        return int(running_time[0].split(" ")[0])
    else: #is a string
        return int(running_time.split(" ")[0])

for movie in movie_info_list:
100, 112, 93, 78, 96, 99, 76, 98, 97, 99, 101, 96, None, 90, 107, 82, 101, 96, 88, 97, 108, 104, 116, 103, 109, 74, 79, 123, 108, 100, 125, 84, 90, 88, 109, 89, 104, 137, 106, 63, 88, 103, 93, 132, 77, 96, 93, 100, 89, 87, 75, 101, 130, 77, 104, 149, 92, 81, 102, 125, 107, 78, 77, 124, 97, 84, 127, 81, 102, 124, 129, 76, 106, 82, 130, 95, 154, 94, 117, 108, 106, 113, 97, 118, 103, 124, 107, 161, 86, 129, 129, 102, None, 162, 114, 105, 109, 118, 104, 99, 112, 131, 112, 76, 128, 100, 118, 119, 104, 100, 103, 114, 99, 102, 107, 78, 86, 95, 160, 85, 100, 95, 115, 110, 122, 101, 121, 95, 107, 134, 95, 128, 102, 58, 108, 82, 100, 107, 91, 84, 97, 105, 105, 111, 105, 103, 118, 102, 75, 77, None, None, None, None, 95, 118, None, None, None, None, 81, 70, None, 90, 93, 91, 78, 85, 124, None, 83, 107, None, 79, 508, 79, 102, 468, 108, 81, 102, 108]

# %%
#Convert budget and box office to floats

# %%
print([movie.get('Budget', 'N/A') for movie in movie_info_list])
# Out:
# ['$1.49 million', '$2.6 million', '$2.28 million', '$600,000', '$950,000', '$858,000', 'N/A', '$788,000', 'N/A', '$1.35 million', '$2.125 million', 'N/A', '$1.5 million', '$1.5 million', 'N/A', '$2.2 million', '$1.8 million', '$3 million', 'N/A', '$4 million', '$2 million', '$300,000', '$1.8 million', 'N/A', '$5 million', 'N/A', '$4 million', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', '$700,000', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', '$6 million', 'under $1 million or $1,250,000', 'N/A', '$2 million', 'N/A', 'N/A', '$2.5 million', 'N/A', 'N/A', '$4 million', '$3.6 million', 'N/A', 'N/A', 'N/A', 'N/A', '$3 million', 'N/A', '$3 million', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', '$3 million', 'N/A', 'N/A', 'N/A', 'N/A', '$4.4–6 million', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', '$4 million', 'N/A', '$5 million', 'N/A', 'N/A', 'N/A', 'N/A', '$5 million', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', '$4 million', 'N/A', 'N/A', 'N/A', '$6.3 million', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', '$5 million', 'N/A', 'N/A', 'N/A', 'N/A', '$8 million', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'AU$1 million', 'N/A', 'N/A', 'N/A', 'N/A', '$5 million', 'N/A', 'N/A', 'N/A', '$7.5 million', 'N/A', '$10 million', 'N/A', 'N/A', '$3.5 to 4 million', 'N/A', 'N/A', 'N/A', '$5.25 million', '$20 million', '$4.5 million', '$9 million', 'N/A', '$6-8 million', '$20 million', 'N/A', 'N/A', '$18 million', '$12 million', '$14 million', '$10 million', '$17 million', '$5 million', '$8 million', '$20 million', '$11 million', '$28 million', '$44 million', 'N/A', '$7.5 million', '$14 million', '$9 million', 'N/A', 'A$8.7 million', '$31 million', '$18 million', '$5 million', '$40 million', '$20 million', 'N/A', '$14 million', '60 million Norwegian Kroner (around $8.7 million in 1989)', 'N/A', '$35-40 million', '$25 million', '$15 million', '$32 million', '$14 million', '$28 million', '$12 million', 'N/A', 'N/A', '$11 million', '$28 million', '$17 million', '$30 million', 'N/A', '$13 million', 'N/A', 'N/A', '$5 million', '$45 million', '$31 million', 'N/A', '$22 million', '$30 million', 'N/A', '$22 million', ['$32 million', '(estimated)'], '$18 million', '$55 million', '$24 million', '$15 million', '$12 million', 'N/A', '$30 million', 'N/A', '$31 million', 'N/A', '$38 million', '$70 million', 'N/A', '$15 million', 'N/A', '$67 million', 'N/A', '$32 million', '$7 million', '$85 million', '$55 million', '$3 million', '$16 million', '$80 million', '$30 million', '$24 million', '$90 million', '$15 million', 'N/A', '$30 million', '$120 million', '$90 million', '$65 million', '$5 million', 'N/A', '$130 million', '$75–90 million', '$10 million', 'N/A', '$90 million', '$15 million –$30 million', 'N/A', '$4,000,000 (estimated)', '$127.5 million', '$80–85 million', '$65 million', 'N/A', 'N/A', '$30 million', '$85 million', '$100 million', '$23 million', 'N/A', '$90–120 million', '$26 million', '$25 million', '$115 million', 'N/A', '$33 million', '$20 million', '$5 million', 'N/A', '$22 million', '$80 million', '$35 million', 'N/A', '$15 million', '$65 million', '$140 million', 'N/A', '$20 million', '$12 million', '$46 million', '$13 million', '$20 million', '$17 million', '$94 million', '$140 million', '$26 million', 'N/A', 'N/A', '$46 million', '$90 million', 'N/A', '$10 million', '$28 million', 'N/A', '$15 million', 'N/A', '$110 million', 'N/A', '$110 million', 'N/A', '$45 million', 'N/A', '$92–145 million', 'N/A', '$100 million', 'N/A', 'N/A', '$20 million', '$56 million', '$25 million', 'N/A', '$50 million', '$35 million', '$35 million', 'N/A', 'N/A', '$25 million', '$150 million', '$180 million', 'N/A', '$30 million', '$1 million', 'N/A', '$40 million', '$50 million', '$80 million', '$120 million', 'N/A', '$225 million', '$30 million', 'N/A', 'N/A', 'N/A', '$8 million', '$17 million', '$150 million', '$300 million', '$150 million', '$25 million', 'N/A', '$22 million', '$85 million', '$130 million', '$7 m ...

# %%
import re

amounts=r"thousand|million|billion"
number = r"\d+(,\d{3})*\.*\d*"

word_re=rf"\${number}(-|\sto\s|–)?({number})?\s({amounts})"
value_re=rf"\${number}"

#money_conversion('$12.2 million') -->12200000 ##word syntax
#money_conversion('$790,000') -->790000 ##value syntax

def word_to_value(word):
    value_dict={'thousand': 1000, 'million': 1000000, 'billion': 1000000000}
    return value_dict[word]

def parse_word_syntax(string):
    value_string=re.search(number, string).group()
    value = float(value_string.replace(',', ''))
    word=re.search(amounts, string, flags=re.I).group().lower()
    word_value=word_to_value(word)
    return value*word_value
    
def parse_value_syntax(string):
    value_string=re.search(number, string).group()
    value = float(value_string.replace(',', ''))
    return value

def money_conversion(money):

    if money == 'N/A':
        return None
    if isinstance(money, list):
        money=money[0]
        
    word_syntax=re.search(word_re, money, flags=re.I)
    value_syntax=re.search(value_re, money)
    
    if word_syntax:
        return parse_word_syntax(word_syntax.group())
    elif value_syntax:
        return parse_value_syntax(value_syntax.group())
    else:
        return None

# %%
for movie in movie_info_list:
    movie['Budget (float)']=money_conversion(movie.get('Budget', 'N/A'))
    movie['Box office (float)']=money_conversion(movie.get('Box office', 'N/A'))

# %%
print([(movie['Budget (float)'], movie['title']) for movie in movie_info_list])
# Out:
# [(1490000.0, 'Snow White and the Seven Dwarfs'), (2600000.0, 'Pinocchio'), (2280000.0, 'Fantasia'), (600000.0, 'The Reluctant Dragon'), (950000.0, 'Dumbo'), (858000.0, 'Bambi'), (None, 'Saludos Amigos'), (788000.0, 'Victory Through Air Power'), (None, 'The Three Caballeros'), (1350000.0, 'Make Mine Music'), (2125000.0, 'Song of the South'), (None, 'Fun and Fancy Free'), (1500000.0, 'Melody Time'), (1500000.0, 'So Dear to My Heart'), (None, 'The Adventures of Ichabod and Mr. Toad'), (2200000.0, 'Cinderella'), (1800000.0, 'Treasure Island'), (3000000.0, 'Alice in Wonderland'), (None, 'The Story of Robin Hood'), (4000000.0, 'Peter Pan'), (2000000.0, 'The Sword and the Rose'), (300000.0, 'The Living Desert'), (1800000.0, 'Rob Roy: The Highland Rogue'), (None, 'The Vanishing Prairie'), (5000000.0, '20,000 Leagues Under the Sea'), (None, 'Davy Crockett: King of the Wild Frontier'), (4000000.0, 'Lady and the Tramp'), (None, 'The African Lion'), (None, 'The Littlest Outlaw'), (None, 'The Great Locomotive Chase'), (None, 'Davy Crockett and the River Pirates'), (None, 'Secrets of Life'), (None, 'Westward Ho the Wagons!'), (700000.0, 'Johnny Tremain'), (None, 'Perri'), (None, 'Old Yeller'), (None, 'The Light in the Forest'), (None, 'White Wilderness'), (None, 'Tonka'), (6000000.0, 'Sleeping Beauty'), (1000000.0, 'The Shaggy Dog'), (None, "Darby O'Gill and the Little People"), (2000000.0, 'Third Man on the Mountain'), (None, 'Toby Tyler or 10 Weeks with a Circus'), (None, 'Kidnapped'), (2500000.0, 'Pollyanna'), (None, 'Jungle Cat'), (None, 'Ten Who Dared'), (4000000.0, 'Swiss Family Robinson'), (3600000.0, 'One Hundred and One Dalmatians'), (None, 'The Absent-Minded Professor'), (None, 'The Parent Trap'), (None, 'Nikki: Wild Dog of the North'), (None, 'Greyfriars Bobby'), (3000000.0, 'Babes in Toyland'), (None, 'Moon Pilot'), (3000000.0, 'Bon Voyage!'), (None, 'Big Red'), (None, 'Almost Angels'), (None, 'The Legend of Lobo'), (None, 'In Search of the Castaways'), (None, 'Son of Flubber'), (None, 'Miracle of the White Stallions'), (None, 'Savage Sam'), (None, 'Summer Magic'), (None, 'The Incredible Journey'), (3000000.0, 'The Sword in the Stone'), (None, 'A Tiger Walks'), (None, 'The Misadventures of Merlin Jones'), (None, 'The Three Lives of Thomasina'), (None, 'The Moon-Spinners'), (4400000.0, 'Mary Poppins'), (None, 'Those Calloways'), (None, 'Emil and the Detectives'), (None, "The Monkey's Uncle"), (None, 'That Darn Cat!'), (None, 'The Ugly Dachshund'), (None, 'Lt. Robin Crusoe, U.S.N.'), (None, 'The Fighting Prince of Donegal'), (None, 'Follow Me, Boys!'), (None, 'Monkeys, Go Home!'), (None, 'The Adventures of Bullwhip Griffin'), (None, 'The Gnome-Mobile'), (4000000.0, 'The Jungle Book'), (None, 'Charlie, the Lonesome Cougar'), (5000000.0, 'The Happiest Millionaire'), (None, "Blackbeard's Ghost"), (None, 'The One and Only, Genuine, Original Family Band'), (None, 'Never a Dull Moment'), (None, 'The Horse in the Gray Flannel Suit'), (5000000.0, 'The Love Bug'), (None, 'Smith!'), (None, 'Rascal'), (None, 'The Computer Wore Tennis Shoes'), (None, 'King of the Grizzlies'), (None, 'The Boatniks'), (None, 'The Wild Country'), (4000000.0, 'The Aristocats'), (None, 'The Barefoot Executive'), (None, 'Scandalous John'), (None, 'The Million Dollar Duck'), (6300000.0, 'Bedknobs and Broomsticks'), (None, 'The Biscuit Eater'), (None, "Now You See Him, Now You Don't"), (None, 'Napoleon and Samantha'), (None, 'Run, Cougar, Run'), (None, 'Snowball Express'), (None, "The World's Greatest Athlete"), (None, 'Charley and the Angel'), (None, 'One Little Indian'), (5000000.0, 'Robin Hood'), (None, 'Superdad'), (None, 'Herbie Rides Again'), (None, 'The Bears and I'), (None, 'The Castaway Cowboy'), (8000000.0, 'The Island at the Top of the World'), (None, 'The Strongest Man in the World'), (None, 'Escape to Witch Mountain'), (None, 'The Apple Dumpling Gang'), (None, 'One of Our Dinosaurs is Missing'), (None, "The Best of Walt Disney's True-Life Adventures"), ( ...

# %%
##CONVERT DATES INTO DATETIME OBJECTS

# %%
for movie in movie_info_list:
    try:
        movie['Release date'] = movie['Release dates']
    except:
        continue

print([('Release date:', movie.get('Release date', 'N/A'), 'Release dates:', movie.get('Release dates', 'N/A')) for movie in movie_info_list])
# Out:
# [('Release date:', ['December 21, 1937 ( Carthay Circle Theatre )', 'February 4, 1938 (United States)'], 'Release dates:', ['December 21, 1937 ( Carthay Circle Theatre )', 'February 4, 1938 (United States)']), ('Release date:', ['February 7, 1940 ( Center Theatre )', 'February 23, 1940 (United States)'], 'Release dates:', ['February 7, 1940 ( Center Theatre )', 'February 23, 1940 (United States)']), ('Release date:', ['November 13, 1940'], 'Release dates:', 'N/A'), ('Release date:', ['June 27, 1941'], 'Release dates:', 'N/A'), ('Release date:', ['October 23, 1941 (New York City)', 'October 31, 1941 (U.S.)'], 'Release dates:', ['October 23, 1941 (New York City)', 'October 31, 1941 (U.S.)']), ('Release date:', ['August 9, 1942 ( London )', 'August 21, 1942 (United States)'], 'Release dates:', ['August 9, 1942 ( London )', 'August 21, 1942 (United States)']), ('Release date:', ['August 24, 1942 (Rio de Janeiro)', 'February 6, 1943 (Boston)', 'February 19, 1943 (United States)'], 'Release dates:', ['August 24, 1942 (Rio de Janeiro)', 'February 6, 1943 (Boston)', 'February 19, 1943 (United States)']), ('Release date:', ['July 17, 1943'], 'Release dates:', 'N/A'), ('Release date:', ['December 21, 1944 (Mexico City)', 'February 3, 1945 (United States)'], 'Release dates:', ['December 21, 1944 (Mexico City)', 'February 3, 1945 (United States)']), ('Release date:', ['April 20, 1946 (New York City)', 'August 15, 1946 (United States)'], 'Release dates:', ['April 20, 1946 (New York City)', 'August 15, 1946 (United States)']), ('Release date:', ['November 12, 1946 (premiere)', 'November 20, 1946'], 'Release dates:', ['November 12, 1946 (premiere)', 'November 20, 1946']), ('Release date:', ['September 27, 1947'], 'Release dates:', 'N/A'), ('Release date:', 'May 27, 1948', 'Release dates:', 'N/A'), ('Release date:', ['November 29, 1948 (Chicago)', 'January 19, 1949 (Indianapolis)'], 'Release dates:', ['November 29, 1948 (Chicago)', 'January 19, 1949 (Indianapolis)']), ('Release date:', ['October 5, 1949'], 'Release dates:', 'N/A'), ('Release date:', ['February 15, 1950 (Boston)', 'March 4, 1950 (United States)'], 'Release dates:', ['February 15, 1950 (Boston)', 'March 4, 1950 (United States)']), ('Release date:', ['June 22, 1950 (London)', 'July 29, 1950 (United States)'], 'Release dates:', ['June 22, 1950 (London)', 'July 29, 1950 (United States)']), ('Release date:', ['July 26, 1951 (London)', 'July 28, 1951 (New York City)', 'September 14, 1951 (United States)'], 'Release dates:', ['July 26, 1951 (London)', 'July 28, 1951 (New York City)', 'September 14, 1951 (United States)']), ('Release date:', ['13 March 1952 (London)', '26 June 1952 (United States)'], 'Release dates:', ['13 March 1952 (London)', '26 June 1952 (United States)']), ('Release date:', ['February 5, 1953'], 'Release dates:', 'N/A'), ('Release date:', ['July 23, 1953 (United States)'], 'Release dates:', 'N/A'), ('Release date:', ['November 10, 1953'], 'Release dates:', 'N/A'), ('Release date:', ['26 October 1953 (London)', '27 February 1954 (United States)'], 'Release dates:', ['26 October 1953 (London)', '27 February 1954 (United States)']), ('Release date:', ['August 17, 1954'], 'Release dates:', 'N/A'), ('Release date:', ['December 23, 1954'], 'Release dates:', 'N/A'), ('Release date:', 'May 25, 1955', 'Release dates:', 'N/A'), ('Release date:', ['June 22, 1955'], 'Release dates:', 'N/A'), ('Release date:', ['September 14, 1955'], 'Release dates:', 'N/A'), ('Release date:', 'December 22, 1955', 'Release dates:', 'N/A'), ('Release date:', 'June 8, 1956', 'Release dates:', 'N/A'), ('Release date:', ['July 18, 1956'], 'Release dates:', 'N/A'), ('Release date:', ['September 4, 1956'], 'Release dates:', 'N/A'), ('Release date:', ['December 20, 1956'], 'Release dates:', 'N/A'), ('Release date:', 'June 19, 1957', 'Release dates:', 'N/A'), ('Release date:', 'August 28, 1957', 'Release dates:', 'N/A'), ('Release date:', ['December 25, 1957'], 'Release dates:', 'N/A'), ('Release dat ...

# %%
from datetime import datetime

dates = [movie.get('Release date', 'N/A') for movie in movie_info_list]

def clean_date(date):
    return date.split('(')[0].strip()

def date_conversion(date):
    if isinstance(date, list):
        date=date[0]
    if date=='N/A':
        return None
        
    date_str=clean_date(date)


    fmts=['%B %d, %Y', '%d %B %Y']
    for fmt in fmts:
        try:
            return datetime.strptime(date_str, fmt)
        except:
            pass
    return None

# %%
for movie in movie_info_list:
    
    movie['Release date (datetime)'] = date_conversion(movie.get('Release date', 'N/A'))

# %%
movie_info_list[-40]
# Out:
# {'title': 'Lightyear',
#  'Directed by': 'Angus MacLane',
#  'Screenplay by': ['Jason Headley', 'Angus MacLane'],
#  'Story by': ['Angus MacLane', 'Matthew Aldrich', 'Jason Headley'],
#  'Produced by': 'Galyn Susman',
#  'Starring': ['Chris Evans',
#   'Keke Palmer',
#   'Peter Sohn',
#   'Taika Waititi',
#   'Dale Soules',
#   'James Brolin',
#   'Uzo Aduba'],
#  'Cinematography': ['Jeremy Lasky (camera)', 'Ian Megibben (lighting)'],
#  'Edited by': 'Anthony J. Greenberg',
#  'Music by': 'Michael Giacchino',
#  'Production companies': ['Walt Disney Pictures', 'Pixar Animation Studios'],
#  'Distributed by': ['Walt Disney Studios', 'Motion Pictures'],
#  'Release dates': ['June 8, 2022 ( El Capitan Theatre )',
#   'June 17, 2022 (United States)'],
#  'Running time': '105 minutes',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$200 million',
#  'Box office': '$226.4 million',
#  'Runnig time (int)': 105,
#  'Running time (int)': 105,
#  'Budget (float)': 200000000.0,
#  'Box office (float)': 226400000.0,
#  'Release date (datetime)': datetime.datetime(2022, 6, 8, 0, 0),
#  'Release date': ['June 8, 2022 ( El Capitan Theatre )',
#   'June 17, 2022 (United States)']}

# %%
import pickle

def save_data_pickle(name, data):
    with open(name, 'wb') as f:
        pickle.dump(data, f)

# %%
import pickle

def load_data_pickle(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
save_data_pickle('disney_movie_data_cleaned.pickle', movie_info_list)

# %%
movie_info_list = load_data_pickle('disney_movie_data_cleaned.pickle')

# %%
##Attach Rotten tomatoes/IMDB/Metascore scores using APIs

# %%
import requests
import urllib
import os


apikey=os.environ['OMDB_API_KEY']

print(apikey)

def get_omdb_info(title):
    base_url= 'http://www.omdbapi.com/?'
    parameters = {'apikey': apikey, 't': title}
    params_encoded = urllib.parse.urlencode(parameters)
    full_url = base_url+params_encoded
    print(full_url)
    return requests.get(full_url).json()

def get_rotten_tomatoes_score(omdb_info):
    ratings=omdb_info.get('Ratings', [])
    for rating in ratings:
        if rating['Source'] == 'Rotten Tomatoes':
            return rating['Value']
    return None
# Out:
# d9a64f74

# %%
for index, movie in enumerate(movie_info_list):
    if index % 10 == 0:
        print(index)
    title=movie['title']
    omdb_info=get_omdb_info(title)
    movie['imdb']=omdb_info.get('imdbRating', None)
    movie['metascore']=omdb_info.get('Metascore', None)
    movie['rotten tomatoes']=get_rotten_tomatoes_score(omdb_info)
# Out:
# 0
# http://www.omdbapi.com/?apikey=d9a64f74&t=Snow+White+and+the+Seven+Dwarfs
# http://www.omdbapi.com/?apikey=d9a64f74&t=Pinocchio
# http://www.omdbapi.com/?apikey=d9a64f74&t=Fantasia
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Reluctant+Dragon
# http://www.omdbapi.com/?apikey=d9a64f74&t=Dumbo
# http://www.omdbapi.com/?apikey=d9a64f74&t=Bambi
# http://www.omdbapi.com/?apikey=d9a64f74&t=Saludos+Amigos
# http://www.omdbapi.com/?apikey=d9a64f74&t=Victory+Through+Air+Power
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Lion+King
# http://www.omdbapi.com/?apikey=d9a64f74&t=Chang+Can+Dunk
# 500
# http://www.omdbapi.com/?apikey=d9a64f74&t=Crater
# http://www.omdbapi.com/?apikey=d9a64f74&t=Peter+Pan+%26+Wendy
# http://www.omdbapi.com/?apikey=d9a64f74&t=Young+Woman+and+the+Sea
# http://www.omdbapi.com/?apikey=d9a64f74&t=Alexander+and+the+Terrible%2C+Horrible%2C+No+Good%2C+Very+Bad+Day
# http://www.omdbapi.com/?apikey=d9a64f74&t=Bambi
# http://www.omdbapi.com/?apikey=d9a64f74&t=Father+of+the+Bride
# http://www.omdbapi.com/?apikey=d9a64f74&t=Flight+of+the+Navigator
# http://www.omdbapi.com/?apikey=d9a64f74&t=Hercules
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Hunchback+of+Notre+Dame
# http://www.omdbapi.com/?apikey=d9a64f74&t=Inspector+Gadget
# 510
# http://www.omdbapi.com/?apikey=d9a64f74&t=Lilo+%26+Stitch
# http://www.omdbapi.com/?apikey=d9a64f74&t=National+Treasure%3A+Book+of+Secrets
# http://www.omdbapi.com/?apikey=d9a64f74&t=
# http://www.omdbapi.com/?apikey=d9a64f74&t=Robin+Hood
# http://www.omdbapi.com/?apikey=d9a64f74&t=SpaceCamp
# http://www.omdbapi.com/?apikey=d9a64f74&t=
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Aristocats
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Parent+Trap
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Sword+in+the+Stone
# http://www.omdbapi.com/?apikey=d9a64f74&t=Three+Men+and+a+Baby
# 520
# http://www.omdbapi.com/?apikey=d9a64f74&t=Tinker+Bell
# http://www.omdbapi.com/?apikey=d9a64f74&t=The+Rocketeer
# http://www.omdbapi.com/?apikey=d9a64f74&t=Toy+Story
# http://www.omdbapi.com/?apikey=d9a64f74&t=Frozen
# http://www.omdbapi.com/?apikey=d9a64f74&t=Zootopia

# %%
movie_info_list[-40]
# Out:
# {'title': 'Lightyear',
#  'Directed by': 'Angus MacLane',
#  'Screenplay by': ['Jason Headley', 'Angus MacLane'],
#  'Story by': ['Angus MacLane', 'Matthew Aldrich', 'Jason Headley'],
#  'Produced by': 'Galyn Susman',
#  'Starring': ['Chris Evans',
#   'Keke Palmer',
#   'Peter Sohn',
#   'Taika Waititi',
#   'Dale Soules',
#   'James Brolin',
#   'Uzo Aduba'],
#  'Cinematography': ['Jeremy Lasky (camera)', 'Ian Megibben (lighting)'],
#  'Edited by': 'Anthony J. Greenberg',
#  'Music by': 'Michael Giacchino',
#  'Production companies': ['Walt Disney Pictures', 'Pixar Animation Studios'],
#  'Distributed by': ['Walt Disney Studios', 'Motion Pictures'],
#  'Release dates': ['June 8, 2022 ( El Capitan Theatre )',
#   'June 17, 2022 (United States)'],
#  'Running time': '105 minutes',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$200 million',
#  'Box office': '$226.4 million',
#  'Runnig time (int)': 105,
#  'Running time (int)': 105,
#  'Budget (float)': 200000000.0,
#  'Box office (float)': 226400000.0,
#  'Release date (datetime)': datetime.datetime(2022, 6, 8, 0, 0),
#  'Release date': ['June 8, 2022 ( El Capitan Theatre )',
#   'June 17, 2022 (United States)'],
#  'imdb': '6.1',
#  'metascore': '60',
#  'rotten tomatoes': '74%'}

# %%
save_data_pickle('disney_movie_data_final.pickle', movie_info_list)

# %%
##SAVE DATA AS CSV

# %%
import pandas as pd

df=pd.DataFrame(movie_info_list)

# %%
df.head()
# Out:
#                              title  \
# 0  Snow White and the Seven Dwarfs
# 1                        Pinocchio
# 2                         Fantasia
# 3             The Reluctant Dragon
# 4                            Dumbo
#
#                                          Directed by  \
# 0  [David Hand, William Cottrell, Wilfred Jackson...
# 1  [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 2  [Samuel Armstrong, James Algar, Bill Roberts, ...
# 3  [Alfred Werker, (live action), Hamilton Luske,...
# 4  [Ben Sharpsteen, Norman Ferguson, Wilfred Jack...
#
#                                           Written by  \
# 0  [Ted Sears, Richard Creedon, Otto Englander, D...
# 1                                                NaN
# 2                                                NaN
# 3  [Live-action:, Ted Sears, Al Perkins, Larry Cl...
# 4                                                NaN
#
#                                             Based on  \
# 0               [Snow White, by The, Brothers Grimm]
# 1   [The Adventures of Pinocchio, by, Carlo Collodi]
# 2                                                NaN
# 3                                                NaN
# 4  [Dumbo, the Flying Elephant, by, Helen Aberson...
#
#                      Produced by  \
# 0                    Walt Disney
# 1                    Walt Disney
# 2  [Walt Disney, Ben Sharpsteen]
# 3                    Walt Disney
# 4                    Walt Disney
#
#                                             Starring  \
# 0  [Adriana Caselotti, Lucille La Verne, Harry St...
# 1  [Cliff Edwards, Dickie Jones, Christian Rub, W...
# 2                  [Leopold Stokowski, Deems Taylor]
# 3  [Robert Benchley, Frances Gifford, Buddy Peppe...
# 4  [Edward Brophy, Verna Felton, Cliff Edwards, H...
#
#                                        Music by       Production company  \
# 0  [Frank Churchill, Paul Smith, Leigh Harline]  Walt Disney Productions
# 1                [Leigh Harline, Paul J. Smith]  Walt Disney Productions
# 2                                   See program  Walt Disney Productions
# 3                [Frank Churchill, Larry Morey]  Walt Disney Productions
# 4             [Frank Churchill, Oliver Wallace]  Walt Disney Productions
#
#        Distributed by                                      Release dates  ...  \
# 0  RKO Radio Pictures  [December 21, 1937 ( Carthay Circle Theatre ),...  ...
# 1  RKO Radio Pictures  [February 7, 1940 ( Center Theatre ), February...  ...
# 2  RKO Radio Pictures                                                NaN  ...
# 3  RKO Radio Pictures                                                NaN  ...
# 4  RKO Radio Pictures  [October 23, 1941 (New York City), October 31,...  ...
#
#   Countries Color process Production companies Layouts by Music  Lyrics  Book  \
# 0       NaN           NaN                  NaN        NaN   NaN     NaN   NaN
# 1       NaN           NaN                  NaN        NaN   NaN     NaN   NaN
# 2       NaN           NaN                  NaN        NaN   NaN     NaN   NaN
# 3       NaN           NaN                  NaN        NaN   NaN     NaN   NaN
# 4       NaN           NaN                  NaN        NaN   NaN     NaN   NaN
#
#    Basis  Productions Awards
# 0    NaN          NaN    NaN
# 1    NaN          NaN    NaN
# 2    NaN          NaN    NaN
# 3    NaN          NaN    NaN
# 4    NaN          NaN    NaN
#
# [5 rows x 40 columns]

# %%
df.to_csv('disney_movie_data.csv')
